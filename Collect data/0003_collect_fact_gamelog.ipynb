# %%
import pandas as pd 
pd.options.display.max_columns = 40

# %% [markdown]
# Load data to CVS

# %%
df = pd.read_csv(r"C:\Users\elian\OneDrive\Escritorio\Jugadores Hockey Proyect\CSV\IN\njd_2023.csv")
team_abv= 'NJD'
season = '2023'
reg_or_playoffs = 'R'

# %%
df.head(3)
# Out:
#   Unnamed: 0  Unnamed: 1 Unnamed: 2           Unnamed: 3 Unnamed: 4  \
# 0         GP        Date        NaN             Opponent         GF
# 1          1  2022-10-13          @  Philadelphia Flyers          2
# 2          2  2022-10-15        NaN    Detroit Red Wings          2
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8 Team Team.1 Team.2 Team.3  \
# 0         GA        NaN        NaN         NaN    S    PIM    PPG    PPO
# 1          5          L        NaN         NaN   37      8      1      3
# 2          5          L        NaN         NaN   39     12      0      3
#
#   Team.4  Unnamed: 14 Opponent Opponent.1 Opponent.2 Opponent.3 Opponent.4  \
# 0    SHG          NaN        S        PIM        PPG        PPO        SHG
# 1      0          NaN       25          8          1          3          0
# 2      0          NaN       22         10          0          4          0
#
#    Unnamed: 20 Advanced (at Even Strength) Advanced (at Even Strength).1  \
# 0          NaN                          CF                            CA
# 1          NaN                          70                            31
# 2          NaN                          63                            34
#
#   Advanced (at Even Strength).2 Advanced (at Even Strength).3  \
# 0                           CF%                            FF
# 1                          69.3                            47
# 2                          64.9                            45
#
#   Advanced (at Even Strength).4 Advanced (at Even Strength).5  \
# 0                            FA                           FF%
# 1                            24                          66.2
# 2                            24                          65.2
#
#   Advanced (at Even Strength).6 Advanced (at Even Strength).7  \
# 0                           FOW                           FOL
# 1                            35                            25
# 2                            25                            19
#
#   Advanced (at Even Strength).8 Advanced (at Even Strength).9  \
# 0                           FO%                          oZS%
# 1                          58.3                          61.0
# 2                          56.8                          69.9
#
#   Advanced (at Even Strength).10
# 0                            PDO
# 1                           80.9
# 2                           76.6

# %%
df = df.loc[:,:'Opponent.4']
df
# Out:
#    Unnamed: 0  Unnamed: 1 Unnamed: 2             Unnamed: 3 Unnamed: 4  \
# 0          GP        Date        NaN               Opponent         GF
# 1           1  2022-10-13          @    Philadelphia Flyers          2
# 2           2  2022-10-15        NaN      Detroit Red Wings          2
# 3           3  2022-10-18        NaN          Anaheim Ducks          4
# 4           4  2022-10-20          @     New York Islanders          4
# ..        ...         ...        ...                    ...        ...
# 78         78  2023-04-04        NaN    Pittsburgh Penguins          5
# 79         79  2023-04-06        NaN  Columbus Blue Jackets          8
# 80         80  2023-04-08          @          Boston Bruins          1
# 81         81  2023-04-11        NaN         Buffalo Sabres          6
# 82         82  2023-04-13          @    Washington Capitals          5
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8 Team Team.1 Team.2 Team.3  \
# 0          GA        NaN        NaN         NaN    S    PIM    PPG    PPO
# 1           5          L        NaN         NaN   37      8      1      3
# 2           5          L        NaN         NaN   39     12      0      3
# 3           2          W        NaN         NaN   41     15      0      3
# 4           1          W        NaN         NaN   43      6      0      3
# ..        ...        ...        ...         ...  ...    ...    ...    ...
# 78          1          W        NaN         NaN   37      8      1      4
# 79          1          W        NaN         NaN   36     24      2      3
# 80          2          L        NaN         NaN   30      4      0      3
# 81          2          W        NaN         NaN   30      4      0      2
# 82          4          W         OT         NaN   34     11      1      2
#
#    Team.4  Unnamed: 14 Opponent Opponent.1 Opponent.2 Opponent.3 Opponent.4
# 0     SHG          NaN        S        PIM        PPG        PPO        SHG
# 1       0          NaN       25          8          1          3          0
# 2       0          NaN       22         10          0          4          0
# 3       0          NaN       20         23          0          4          0
# 4       0          NaN       17          8          0          2          0
# ..    ...          ...      ...        ...        ...        ...        ...
# 78      0          NaN       23          8          0          4          0
# 79      1          NaN       17         20          0          5          0
# 80      0          NaN       40         10          1          1          0
# 81      0          NaN       38          4          0          2          0
# 82      0          NaN       31         11          0          1          0
#
# [83 rows x 20 columns]

# %%
df.drop(columns=['Unnamed: 8','Unnamed: 14'],inplace=True)
df.head(3)
# Out:
#   Unnamed: 0  Unnamed: 1 Unnamed: 2           Unnamed: 3 Unnamed: 4  \
# 0         GP        Date        NaN             Opponent         GF
# 1          1  2022-10-13          @  Philadelphia Flyers          2
# 2          2  2022-10-15        NaN    Detroit Red Wings          2
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Team Team.1 Team.2 Team.3 Team.4 Opponent  \
# 0         GA        NaN        NaN    S    PIM    PPG    PPO    SHG        S
# 1          5          L        NaN   37      8      1      3      0       25
# 2          5          L        NaN   39     12      0      3      0       22
#
#   Opponent.1 Opponent.2 Opponent.3 Opponent.4
# 0        PIM        PPG        PPO        SHG
# 1          8          1          3          0
# 2         10          0          4          0

# %%
df.rename(columns={'Unnamed: 0':'GP', 'Unnamed: 1':"Date", 'Unnamed: 2':"Home", 'Unnamed: 3':"Opp_Name", 'Unnamed: 4':"GF",
       'Unnamed: 5':"GA", 'Unnamed: 6':"Result", 'Unnamed: 7':"OT", 'Team':"Team_S", 'Team.1':"Team_PIM", 'Team.2':"Team_PPG",
       'Team.3':"Team_PPO", 'Team.4':"Team_SHG", 'Opponent':"Opp_S", 'Opponent.1':"Opp_PIM", 'Opponent.2':"Opp_PPG",
       'Opponent.3':"Opp_PPO", 'Opponent.4':"Opp_SHG"},inplace=True)

df.head(2)
# Out:
#    GP        Date Home             Opp_Name  GF  GA Result   OT Team_S  \
# 0  GP        Date  NaN             Opponent  GF  GA    NaN  NaN      S
# 1   1  2022-10-13    @  Philadelphia Flyers   2   5      L  NaN     37
#
#   Team_PIM Team_PPG Team_PPO Team_SHG Opp_S Opp_PIM Opp_PPG Opp_PPO Opp_SHG
# 0      PIM      PPG      PPO      SHG     S     PIM     PPG     PPO     SHG
# 1        8        1        3        0    25       8       1       3       0

# %%
df.drop(0,inplace=True)
df.head(3)
# Out:
#   GP        Date Home             Opp_Name GF GA Result   OT Team_S Team_PIM  \
# 1  1  2022-10-13    @  Philadelphia Flyers  2  5      L  NaN     37        8
# 2  2  2022-10-15  NaN    Detroit Red Wings  2  5      L  NaN     39       12
# 3  3  2022-10-18  NaN        Anaheim Ducks  4  2      W  NaN     41       15
#
#   Team_PPG Team_PPO Team_SHG Opp_S Opp_PIM Opp_PPG Opp_PPO Opp_SHG
# 1        1        3        0    25       8       1       3       0
# 2        0        3        0    22      10       0       4       0
# 3        0        3        0    20      23       0       4       0

# %%
df.Home = [0 if x =='@'else 1 for x in df.Home]
df.OT = [1 if x == 'NaN' else 0 for x in df.OT]
df
# Out:
#     GP        Date  Home               Opp_Name GF GA Result  OT Team_S  \
# 1    1  2022-10-13     0    Philadelphia Flyers  2  5      L   0     37
# 2    2  2022-10-15     1      Detroit Red Wings  2  5      L   0     39
# 3    3  2022-10-18     1          Anaheim Ducks  4  2      W   0     41
# 4    4  2022-10-20     0     New York Islanders  4  1      W   0     43
# 5    5  2022-10-22     1        San Jose Sharks  2  1      W   0     36
# ..  ..         ...   ...                    ... .. ..    ...  ..    ...
# 78  78  2023-04-04     1    Pittsburgh Penguins  5  1      W   0     37
# 79  79  2023-04-06     1  Columbus Blue Jackets  8  1      W   0     36
# 80  80  2023-04-08     0          Boston Bruins  1  2      L   0     30
# 81  81  2023-04-11     1         Buffalo Sabres  6  2      W   0     30
# 82  82  2023-04-13     0    Washington Capitals  5  4      W   0     34
#
#    Team_PIM Team_PPG Team_PPO Team_SHG Opp_S Opp_PIM Opp_PPG Opp_PPO Opp_SHG
# 1         8        1        3        0    25       8       1       3       0
# 2        12        0        3        0    22      10       0       4       0
# 3        15        0        3        0    20      23       0       4       0
# 4         6        0        3        0    17       8       0       2       0
# 5         4        1        3        0    22       6       0       2       0
# ..      ...      ...      ...      ...   ...     ...     ...     ...     ...
# 78        8        1        4        0    23       8       0       4       0
# 79       24        2        3        1    17      20       0       5       0
# 80        4        0        3        0    40      10       1       1       0
# 81        4        0        2        0    38       4       0       2       0
# 82       11        1        2        0    31      11       0       1       0
#
# [82 rows x 18 columns]

# %%
df['Team_Abv'] = team_abv
df['Season'] = reg_or_playoffs
df['Season_Year']= season

# %%
team_abv_names= pd.read_csv(r"C:\Users\elian\OneDrive\Escritorio\Jugadores Hockey Proyect\CSV\IN\team_abv.csv")
team_abv_names.head(5)
# Out:
#    ABV             Team  ID
# 0  ANA    Anaheim Ducks   1
# 1  ARI  Arizona Coyotes   2
# 2  BOS    Boston Bruins   3
# 3  BUF   Buffalo Sabres   4
# 4  CGY   Calgary Flames   5

# %%
df = df.merge(team_abv_names, left_on=['Team_Abv'], right_on=['ABV'], how='left')
df.head(5)
# Out:
#   GP        Date  Home             Opp_Name GF GA Result  OT Team_S Team_PIM  \
# 0  1  2022-10-13     0  Philadelphia Flyers  2  5      L   0     37        8
# 1  2  2022-10-15     1    Detroit Red Wings  2  5      L   0     39       12
# 2  3  2022-10-18     1        Anaheim Ducks  4  2      W   0     41       15
# 3  4  2022-10-20     0   New York Islanders  4  1      W   0     43        6
# 4  5  2022-10-22     1      San Jose Sharks  2  1      W   0     36        4
#
#   Team_PPG Team_PPO Team_SHG Opp_S Opp_PIM Opp_PPG Opp_PPO Opp_SHG Team_Abv  \
# 0        1        3        0    25       8       1       3       0      NJD
# 1        0        3        0    22      10       0       4       0      NJD
# 2        0        3        0    20      23       0       4       0      NJD
# 3        0        3        0    17       8       0       2       0      NJD
# 4        1        3        0    22       6       0       2       0      NJD
#
#   Season Season_Year  ABV               Team  ID
# 0      R        2023  NJD  New Jersey Devils  18
# 1      R        2023  NJD  New Jersey Devils  18
# 2      R        2023  NJD  New Jersey Devils  18
# 3      R        2023  NJD  New Jersey Devils  18
# 4      R        2023  NJD  New Jersey Devils  18

# %%
df.rename(columns={'ID':'team_id'},inplace=True)
df.drop(columns='ABV', inplace=True)
df.head(5)
# Out:
#   GP        Date  Home             Opp_Name GF GA Result  OT Team_S Team_PIM  \
# 0  1  2022-10-13     0  Philadelphia Flyers  2  5      L   0     37        8
# 1  2  2022-10-15     1    Detroit Red Wings  2  5      L   0     39       12
# 2  3  2022-10-18     1        Anaheim Ducks  4  2      W   0     41       15
# 3  4  2022-10-20     0   New York Islanders  4  1      W   0     43        6
# 4  5  2022-10-22     1      San Jose Sharks  2  1      W   0     36        4
#
#   Team_PPG Team_PPO Team_SHG Opp_S Opp_PIM Opp_PPG Opp_PPO Opp_SHG Team_Abv  \
# 0        1        3        0    25       8       1       3       0      NJD
# 1        0        3        0    22      10       0       4       0      NJD
# 2        0        3        0    20      23       0       4       0      NJD
# 3        0        3        0    17       8       0       2       0      NJD
# 4        1        3        0    22       6       0       2       0      NJD
#
#   Season Season_Year               Team  team_id
# 0      R        2023  New Jersey Devils       18
# 1      R        2023  New Jersey Devils       18
# 2      R        2023  New Jersey Devils       18
# 3      R        2023  New Jersey Devils       18
# 4      R        2023  New Jersey Devils       18

# %% [markdown]
# create a primary key

# %%
df['Key']= df['team_id'].astype(str)+'-'+season+'-'+reg_or_playoffs+df['GP'].astype(str)
# Out:
#   GP        Date  Home             Opp_Name GF GA Result  OT Team_S Team_PIM  \
# 0  1  2022-10-13     0  Philadelphia Flyers  2  5      L   0     37        8
# 1  2  2022-10-15     1    Detroit Red Wings  2  5      L   0     39       12
# 2  3  2022-10-18     1        Anaheim Ducks  4  2      W   0     41       15
# 3  4  2022-10-20     0   New York Islanders  4  1      W   0     43        6
# 4  5  2022-10-22     1      San Jose Sharks  2  1      W   0     36        4
#
#   Team_PPG Team_PPO Team_SHG Opp_S Opp_PIM Opp_PPG Opp_PPO Opp_SHG Team_Abv  \
# 0        1        3        0    25       8       1       3       0      NJD
# 1        0        3        0    22      10       0       4       0      NJD
# 2        0        3        0    20      23       0       4       0      NJD
# 3        0        3        0    17       8       0       2       0      NJD
# 4        1        3        0    22       6       0       2       0      NJD
#
#   Season Season_Year               Team  team_id         Key
# 0      R        2023  New Jersey Devils       18  18-2023-R1
# 1      R        2023  New Jersey Devils       18  18-2023-R2
# 2      R        2023  New Jersey Devils       18  18-2023-R3
# 3      R        2023  New Jersey Devils       18  18-2023-R4
# 4      R        2023  New Jersey Devils       18  18-2023-R5

# %%
#clean date
df['Date']= df.Date.astype(str)
df['Date'] = df.Date.str.replace('-','')
df.head(5)
# Out:
#   GP      Date  Home             Opp_Name GF GA Result  OT Team_S Team_PIM  \
# 0  1  20221013     0  Philadelphia Flyers  2  5      L   0     37        8
# 1  2  20221015     1    Detroit Red Wings  2  5      L   0     39       12
# 2  3  20221018     1        Anaheim Ducks  4  2      W   0     41       15
# 3  4  20221020     0   New York Islanders  4  1      W   0     43        6
# 4  5  20221022     1      San Jose Sharks  2  1      W   0     36        4
#
#   Team_PPG Team_PPO Team_SHG Opp_S Opp_PIM Opp_PPG Opp_PPO Opp_SHG Team_Abv  \
# 0        1        3        0    25       8       1       3       0      NJD
# 1        0        3        0    22      10       0       4       0      NJD
# 2        0        3        0    20      23       0       4       0      NJD
# 3        0        3        0    17       8       0       2       0      NJD
# 4        1        3        0    22       6       0       2       0      NJD
#
#   Season Season_Year               Team  team_id         Key
# 0      R        2023  New Jersey Devils       18  18-2023-R1
# 1      R        2023  New Jersey Devils       18  18-2023-R2
# 2      R        2023  New Jersey Devils       18  18-2023-R3
# 3      R        2023  New Jersey Devils       18  18-2023-R4
# 4      R        2023  New Jersey Devils       18  18-2023-R5
